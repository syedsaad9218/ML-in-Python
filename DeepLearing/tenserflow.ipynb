# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (6.33.6)
# Requirement already satisfied: requests<3,>=2.21.0 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (2.34.2)
# Requirement already satisfied: setuptools in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (81.0.0)
# Requirement already satisfied: six>=1.12.0 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (2.4.3)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from keras>=3.12.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
import tensorflow as tf

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
train_images = train_images.reshape(
    (train_images.shape[0], 28 * 28)).astype('float32') / 255
test_images = test_images.reshape(
    (test_images.shape[0], 28 * 28)).astype('float32') / 255

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(28 * 28,)),
    Dense(10, activation='softmax')
])
# Out:
# c:\Users\SYED SAAD AHMED\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
model.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9273 - loss: 0.2565
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9668 - loss: 0.1130
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9767 - loss: 0.0766
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9832 - loss: 0.0570
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9866 - loss: 0.0441

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9781 - loss: 0.0719
# Test accuracy: 0.9781000018119812
