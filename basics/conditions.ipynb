# %%
a = 23
b = 20

if a <= b :
    print("yes")

elif a >= b :
    print("a is big")

else :
    print("nothing")
# Out:
# a is big

# %%
consider = False

a = 23


if a == 23 :
    print("yes")
    consider = True
    a = 20
    print(a)

else :
     print("no")
# Out:
# yes
# 20

# %%
for i in range(10):
    print("hello")
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello

# %%
a = int(input("enter a number"))


for i in range(a):
    print(i,"hello")
# Out:
# 0 hello
# 1 hello
# 2 hello
# 3 hello
# 4 hello
# 5 hello
# 6 hello
# 7 hello
# 8 hello
# 9 hello
# 10 hello
# 11 hello
# 12 hello
# 13 hello
# 14 hello
# 15 hello
# 16 hello
# 17 hello
# 18 hello
# 19 hello
# 20 hello
# 21 hello
# 22 hello
# 23 hello
# 24 hello
# 25 hello
